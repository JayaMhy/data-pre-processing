# %%
# Program to remove comments

import glob
import re

filenames = glob.glob('./vulnerable_clean/*.c', 
                   recursive = True)
for filename in filenames:
    with open(filename, 'r') as f:
        source_code = f.read()
        
    cleaned_filename = re.sub(r'^./vulnerable_clean/', r'new_cleaned/', filename)

    with open(cleaned_filename, 'w') as f:
        clean_source_code = source_code
        #regex to remove all multi line c comments
        clean_source_code = re.sub(r'/\*.*?\*/', '', clean_source_code, flags=re.DOTALL)
        #regex to remove all single line c comments
        clean_source_code = re.sub(r'\/\/.*', '', clean_source_code)

        f.write(clean_source_code)

# %%
import glob
import re

filenames = glob.glob('./vulnerable_clean/*.c', 
                   recursive = True)
print(filenames)
# Out:
# ['./vulnerable_clean/cve_cwe_val_44429.c', './vulnerable_clean/cve_cwe_val_17688.c', './vulnerable_clean/cve_cwe_val_125141.c', './vulnerable_clean/cve_cwe_val_13279.c', './vulnerable_clean/cve_cwe_val_96511.c', './vulnerable_clean/cve_cwe_val_105986.c', './vulnerable_clean/cve_cwe_val_50117.c', './vulnerable_clean/cve_cwe_val_49652.c', './vulnerable_clean/cve_cwe_val_12679.c', './vulnerable_clean/cve_cwe_val_126582.c', './vulnerable_clean/cve_cwe_val_12866.c', './vulnerable_clean/cve_cwe_val_45029.c', './vulnerable_clean/cve_cwe_val_64079.c', './vulnerable_clean/cve_cwe_val_105455.c', './vulnerable_clean/cve_cwe_val_94945.c', './vulnerable_clean/cve_cwe_val_34493.c', './vulnerable_clean/cve_cwe_val_46662.c', './vulnerable_clean/cve_cwe_val_62297.c', './vulnerable_clean/cve_cwe_val_6655.c', './vulnerable_clean/cve_cwe_val_26207.c', './vulnerable_clean/cve_cwe_val_55925.c', './vulnerable_clean/cve_cwe_val_76465.c', './vulnerable_clean/cve_cwe_val_96289.c', './vulnerable_clean/cve_cwe_val_8321.c', './vulnerable_clean/cve_cwe_val_93213.c', './vulnerable_clean/cve_cwe_val_111887.c', './vulnerable_clean/cve_cwe_val_123008.c', './vulnerable_clean/cve_cwe_val_5131.c', './vulnerable_clean/cve_cwe_val_74645.c', './vulnerable_clean/cve_cwe_val_101948.c', './vulnerable_clean/cve_cwe_val_44152.c', './vulnerable_clean/cve_cwe_val_95765.c', './vulnerable_clean/cve_cwe_val_63530.c', './vulnerable_clean/cve_cwe_val_101757.c', './vulnerable_clean/cve_cwe_val_50528.c', './vulnerable_clean/cve_cwe_val_18287.c', './vulnerable_clean/cve_cwe_val_72333.c', './vulnerable_clean/cve_cwe_val_19687.c', './vulnerable_clean/cve_cwe_val_35624.c', './vulnerable_clean/cve_cwe_val_85566.c', './vulnerable_clean/cve_cwe_val_123280.c', './vulnerable_clean/cve_cwe_val_73677.c', './vulnerable_clean/cve_cwe_val_108099.c', './vulnerable_clean/cve_cwe_val_47591.c', './vulnerable_clean/cve_cwe_val_45416.c', './vulnerable_clean/cve_cwe_val_24163.c', './vulnerable_clean/cve_cwe_val_123518.c', './vulnerable_clean/cve_cwe_val_91684.c', './vulnerable_clean/cve_cwe_val_115779.c', './vulnerable_clean/cve_cwe_val_120353.c', './vulnerable_clean/cve_cwe_val_29953.c', './vulnerable_clean/cve_cwe_val_32306.c', './vulnerable_clean/cve_cwe_val_84476.c', './vulnerable_clean/cve_cwe_val_120217.c', './vulnerable_clean/cve_cwe_val_30281.c', './vulnerable_clean/cve_cwe_val_92247.c', './vulnerable_clean/cve_cwe_val_28208.c', './vulnerable_clean/cve_cwe_val_89749.c', './vulnerable_clean/cve_cwe_val_20082.c', './vulnerable_clean/cve_cwe_val_23992.c', './vulnerable_clean/cve_cwe_val_68669.c', './vulnerable_clean/cve_cwe_val_27238.c', './vulnerable_clean/cve_cwe_val_99899.c', './vulnerable_clean/cve_cwe_val_102684.c', './vulnerable_clean/cve_cwe_val_2413.c', './vulnerable_clean/cve_cwe_val_85852.c', './vulnerable_clean/cve_cwe_val_8125.c', './vulnerable_clean/cve_cwe_val_11939.c', './vulnerable_clean/cve_cwe_val_18324.c', './vulnerable_clean/cve_cwe_val_27403.c', './vulnerable_clean/cve_cwe_val_33079.c', './vulnerable_clean/cve_cwe_val_122667.c', './vulnerable_clean/cve_cwe_val_21175.c', './vulnerable_clean/cve_cwe_val_38630.c', './vulnerable_clean/cve_cwe_val_41000.c', './vulnerable_clean/cve_cwe_val_60050.c', './vulnerable_clean/cve_cwe_val_47432.c', './vulnerable_clean/cve_cwe_val_44279.c', './vulnerable_clean/cve_cwe_val_71653.c', './vulnerable_clean/cve_cwe_val_93138.c', './vulnerable_clean/cve_cwe_val_61004.c', './vulnerable_clean/cve_cwe_val_43944.c', './vulnerable_clean/cve_cwe_val_26984.c', './vulnerable_clean/cve_cwe_val_105715.c', './vulnerable_clean/cve_cwe_val_117806.c', './vulnerable_clean/cve_cwe_val_95292.c', './vulnerable_clean/cve_cwe_val_64339.c', './vulnerable_clean/cve_cwe_val_16204.c', './vulnerable_clean/cve_cwe_val_104315.c', './vulnerable_clean/cve_cwe_val_38320.c', './vulnerable_clean/cve_cwe_val_53558.c', './vulnerable_clean/cve_cwe_val_44976.c', './vulnerable_clean/cve_cwe_val_125201.c', './vulnerable_clean/cve_cwe_val_88126.c', './vulnerable_clean/cve_cwe_val_4998 ...
